# %%
# write

import pickle

path_file_path="./object_path.pkl"

paths_list=["../data/00a59dba4dc3432a97faa83e06adb644.ply"]

with open(path_file_path, 'wb') as F:  
    pickle.dump(paths_list, F)

# %%
# read

import pickle

path_file_path="C:\\Users\\Lenovo\\Desktop\\UniMesh_und\\UniMesh\\DiffuRank\\example_material\\example_object_path.pkl"

with open(path_file_path, 'rb') as f:
    obj = pickle.load(f)
print(obj[:5])
# Out:
# ['./example_material/glbs/9bc465a181f349908b95d030f541663a.glb', './example_material/glbs/db7339a98f464ff38e3c3e32c924ca65.glb', './example_material/glbs/862b7c8cae7e4f8ebc98ee3fd71bdc39.glb', './example_material/glbs/e2ec7e244a1b4e328c92f57b4709257e.glb', './example_material/glbs/b416732d162e4e4d92ee9a37c65fedbc.glb']
