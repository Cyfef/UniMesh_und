# %% [markdown]
# # Qwen2.5-VL

# %%
git clone https://huggingface.co/Qwen/Qwen2.5-VL-3B-Instruct

# %% [markdown]
# # Environment

# %%
conda create -n qwen python=3.10 -y
conda activate qwen

pip install modelscope
pip install qwen-vl-utils

# %% [markdown]
# # Model

# %%
from huggingface_hub import snapshot_download

save_dir = "./models/Qwen/Qwen2.5-VL-3B-Instruct"
repo_id = "Qwen/Qwen2.5-VL-3B-Instruct"
cache_dir = save_dir + "/cache"

snapshot_download(
  cache_dir=cache_dir,
  local_dir=save_dir,
  repo_id=repo_id,
  local_dir_use_symlinks=False,
  resume_download=True,
  )

# %%
from huggingface_hub import snapshot_download

save_dir = "./models/Qwen/Qwen2.5-VL-7B-Instruct"
repo_id = "Qwen/Qwen2.5-VL-7B-Instruct"
cache_dir = save_dir + "/cache"

snapshot_download(
  cache_dir=cache_dir,
  local_dir=save_dir,
  repo_id=repo_id,
  local_dir_use_symlinks=False,
  resume_download=True,
  )

# %% [markdown]
# # Run

# %%
python qwen3B_6.py

# %%
python qwen7B_6.py
