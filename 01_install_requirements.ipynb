# %% [markdown]
# conda create --override-channels -c defaults -n bagel python=3.10
#
# 使用 tsinghua channel 會報錯，故使用默認 channel。

# %%
pip install jupyter

# %%
print("hello")

# %%
# !pip install torch==2.6 torchvision

# %%
import subprocess
import os

result = subprocess.run('bash -c "source /etc/network_turbo && env | grep proxy"', shell=True, capture_output=True, text=True)
output = result.stdout
for line in output.splitlines():
    if '=' in line:
        var, value = line.split('=', 1)
        os.environ[var] = value

# %%
# !pip install flash-attn==2.7.4.post1 --no-build-isolation

# %%
# !pip install decord==0.6.0

# %%
# !pip install einops==0.8.1

# %%
# !pip install huggingface_hub==0.29.1

# %%
# !pip install matplotlib==3.7.0

# %%
# !pip install numpy==1.24.4

# %%
pip install opencv_python==4.7.0.72

# %%
pip install pyarrow==11.0.0

# %%
# !pip install PyYAML==6.0.2

# %%
# !pip install Requests==2.32.3

# %%
# !pip install safetensors==0.4.5

# %%
# !pip install scipy==1.10.1

# %%
# !pip install sentencepiece==0.1.99

# %%
# !pip install transformers==4.49.0

# %%
# !pip install accelerate>=0.34.0

# %% [markdown]
# # draft. deprecated. Do not use!

# %%
# https://github.com/ByteDance-Seed/Bagel/issues/48#issuecomment-2910156972



# !pip install torch==2.5.1 torchvision==0.20.1

# %%
import subprocess
import os

result = subprocess.run('bash -c "source /etc/network_turbo && env | grep proxy"', shell=True, capture_output=True, text=True)
output = result.stdout
for line in output.splitlines():
    if '=' in line:
        var, value = line.split('=', 1)
        os.environ[var] = value

# %%
# https://github.com/Dao-AILab/flash-attention/issues/1038

# ! MAX_JOBS=32 pip install flash_attn==2.5.8 --no-build-isolation

# !MAX_JOBS=64 python -m pip -v install flash-attn==2.5.8 --no-build-isolation
