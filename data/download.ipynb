# %% [markdown]
# # Cap3D dataset

# %%
from huggingface_hub import snapshot_download
from huggingface_hub import hf_hub_download
from pathlib import Path

local_dir=Path("")

snapshot_download(
    local_dir=local_dir,
    cache_dir=local_dir/"cache",
    repo_id="tiange/Cap3D",
    repo_type="dataset", 
    allow_patterns=[
        "Cap3D_automated_Objaverse_full.csv",
        "misc/Cap3D_human_Objaverse.pkl",
        "RenderedImage_perobj_zips/compressed_imgs_perobj_000.zip",
        "RenderedImage_perobj_zips/compressed_imgs_perobj_001.zip",
        "RenderedImage_perobj_zips/compressed_imgs_perobj_002.zip",
        "RenderedImage_perobj_zips/compressed_imgs_perobj_003.zip",
        "RenderedImage_perobj_zips/compressed_imgs_perobj_004.zip",
        "RenderedImage_perobj_zips/compressed_imgs_perobj_005.zip",
        "RenderedImage_perobj_zips/compressed_imgs_perobj_006.zip",
    ]
)
