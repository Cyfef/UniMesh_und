# %% [markdown]
# # Phi-4-multimodel

# %% [markdown]
# # Environment

# %%
conda create -n phi4 python=3.10 -y
conda activate phi4
pip install -r requirements.txt

# %% [markdown]
# # Model

# %%
import os
os.environ['HF_ENDPOINT'] = 'https://hf-mirror.com'

# %%
from huggingface_hub import snapshot_download

save_dir = "./models/microsoft/Phi-4-multimodel-instruct"
repo_id = "microsoft/Phi-4-multimodel-instruct"
cache_dir = save_dir + "/cache"

snapshot_download(
  cache_dir=cache_dir,
  local_dir=save_dir,
  repo_id=repo_id,
  local_dir_use_symlinks=False,
  resume_download=True,
  )

# %% [markdown]
# # Run

# %%
python Phi4_6.py
