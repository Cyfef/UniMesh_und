# %% [markdown]
# # Kimi-VL

# %% [markdown]
# # Environment

# %%
conda create -n kimi python=3.10 -y
conda activate kimi
pip install -r requirements.txt

# %% [markdown]
# # Model

# %%
import os
os.environ['HF_ENDPOINT'] = 'https://hf-mirror.com'

# %%
from huggingface_hub import snapshot_download

save_dir = "./models/moonshotai/Kimi-VL-A3B-Thinking-2506"
repo_id = "moonshotai/Kimi-VL-A3B-Thinking-2506"
cache_dir = save_dir + "/cache"

snapshot_download(
  cache_dir=cache_dir,
  local_dir=save_dir,
  repo_id=repo_id,
  local_dir_use_symlinks=False,
  resume_download=True,
  )

# %%
from huggingface_hub import snapshot_download

save_dir = "./models/moonshotai/Kimi-VL-A3B-Instruct"
repo_id = "moonshotai/Kimi-VL-A3B-Instruct"
cache_dir = save_dir + "/cache"

snapshot_download(
  cache_dir=cache_dir,
  local_dir=save_dir,
  repo_id=repo_id,
  local_dir_use_symlinks=False,
  resume_download=True,
  )

# %% [markdown]
# # Run

# %%
python KimiVL_instruct_6.py

# %%
python KimiVL_think_6.py
